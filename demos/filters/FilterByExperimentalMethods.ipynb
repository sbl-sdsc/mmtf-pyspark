# %% [markdown]
# # Filter By Experimental Methods Demo
#
# Example how to filter PDB entries by experimental methods.
#
#
# [To learn more about experimental methods](http://pdb101.rcsb.org/learn/guide-to-understanding-pdb-data/methods-for-determining-structure)
#
#
# ## Imports

# %%
from pyspark.sql import SparkSession
from mmtfPyspark.io import mmtfReader
from mmtfPyspark.filters import ExperimentalMethods
from mmtfPyspark.structureViewer import view_structure

# %% [markdown]
# #### Configure Spark

# %%
spark = SparkSession.builder.master("local[*]") \
                                 .appName("FilterByExperimentalMethods") \
                                 .getOrCreate()

# %% [markdown]
# ## Read in MMTF Files

# %%
path = "../../resources/mmtf_reduced_sample/"

pdb = mmtfReader.read_sequence_file(path)

# %% [markdown]
# ## Filter by experimental methods
#
# #### List of supported experimental methods
#
# * ExperimentalMethods.ELECTRON_CRYSTALLOGRAPHY
# * ExperimentalMethods.ELECTRON_MICROSCOPY
# * ExperimentalMethods.ERP
# * ExperimentalMethods.FIBER_DIFFRACTION
# * ExperimentalMethods.FLUORESCENCE_TRANSFER
# * ExperimentalMethods.INFRARED_SPECTROSCOPY
# * ExperimentalMethods.NEUTRON_DIFFRACTION
# * ExperimentalMethods.POWDER_DIFFRACTION
# * ExperimentalMethods.SOLID_STATE_NMR
# * ExperimentalMethods.SOLUTION_NMR
# * ExperimentalMethods.SOLUTION_SCATTERING
# * ExperimentalMethods.THEORETICAL_MODEL
# * ExperimentalMethods.X_RAY_DIFFRACTION

# %%
pdb = pdb.filter(ExperimentalMethods(ExperimentalMethods.NEUTRON_DIFFRACTION, ExperimentalMethods.X_RAY_DIFFRACTION))

# %% [markdown]
# ## Print out entries

# %%
filtered_structures = pdb.keys().collect()

print(filtered_structures)
# Out:
# ['1LBU', '1LC0', '1LC5', '1LFP', '1LFW', '1LGH', '1LH0', '1LJ8', '1LKI', '1LMI', '1LML', '1LO7', '1LQ9', '1LQV', '1LR0', '1LR5', '1LRI', '1LRZ', '1LS1', '1LTS', '1LU0', '1LU4', '1LUA', '1LUC', '1LUZ', '1LV7', '1LXJ', '1LY1', '1LZL', '1M0D', '1M0K', '4XJ5', '4XLG', '4XLY', '4XNV', '4XO1', '4XOM', '4XP7', '4XPL', '4XPQ', '4XPX', '4XRF', '4XRM', '4XT1', '4XTB', '4XTL', '4XU6', '4XUK', '4XUO', '4XUR', '4XUV', '4XUW', '4XV2', '4XWJ', '4XWW', '4XXI', '4XY5', '4XYW', '1P1J', '1P1M', '1P33', '1P35', '1P3C', '5W2L', '5W8X', '5W95', '5WLJ', '5X89', '5XXS', '6AMG', '6EUW', '6F8P', '5KDZ', '5NF2', '5NF4', '5WAS', '5YHR', '5YK0', '5YK2', '5YQG', '6C8R', '4YNH', '4YNX', '4YOA', '4YOR', '4YP6', '4YPC', '4YPM', '4YPN', '4YQD', '1GCI', '1GCQ', '1GJW', '1GK9', '1GKM', '1GL4', '1GMI', '1GML', '1GMU', '1GMX', '1GNL', '1GNY', '1GO3', '1GP6', '1GPJ', '1GPP', '1GPR', '1GQE', '1GS4', '1GS5', '1GS9', '1GSA', '1GSM', '1GU7', '1GUI', '1GUT', '1GVE', '1GVN', '1GVP', '1GWE', '5WZF', '5X3G', '5XI8', '6B89', '5N81', '5UFN', '5UPH', '5XBC', '1C0P', '1C4O', '1C4Q', '1C7K', '1C94', '1CC8', '1CXQ', '1D1G', '1D4S', '1D9C', '1DLE', '1DM9', '1ES5', '1ET1', '1EUW', '1F0X', '1F1E', '1F1M', '1F3V', '1FG7', '1FJH', '1FOB', '1G12', '1G8E', '1G8M', '1GA6', '1GHE', '1GJ7', '1HRK', '4MAK', '4MAQ', '4MAX', '4MB0', '4MB7', '4MC3', '4MCW', '4MDA', '4ME2', '4MEJ', '4MES', '4MF5', '4MFI', '4MFK', '4MGQ', '4MHL', '4MI7', '4MI8', '4MIJ', '4MJK', '4MKC', '4MKO', '4MKX', '4ML9', '4MM2', '4MN5', '4MNC', '4MNN', '4MNO', '4MO0', '4MP0', '4MPT', '4MR0', '4MRS', '4MS4', '4MSX', '4MT8', '4MTU', '4MUO', '4MUQ', '4MUV', '3SK2', '3SK7', '3SK9', '3SKQ', '3SL9', '3SLR', '3SM2', '3SMV', '3SNY', '3SO9', '3SOA', '3SOJ', '3SPK', '3SQZ', '3SRE', '3SRI', '3SRJ', '3SS7', '3SUU', '3SWY', '3SX6', '3SXR', '3SXU', '3SY1', '3SZV', '3T0Y', '3T1O', '3T2C', '3T3L', '5KVB', '5WAN', '5WCJ', '5XUN', '3T4L', '3T4R', '3T5N', '3T5X', '3T7A', '3T7D', '3T7H', '3T7L', '3T7Z', '3T8K', '3T9O', '3T9Y', '3TAC', '3TAH', '3TBD', '3TBN', '3TBO', '3TC3', '3TCV', '3TDG', '3TDN', '3TE8', '3TEE', '3TEK', '3TEQ', '3TEU', '3TEW', '3TFG', '3TFJ', '3TG2', '3TG7', '3TG9', '3THG', '3THI', '3TI1', '3TJ8', '3TJM', '3TJY', '3TLQ', '3TM4', '3TM8', '3TMG', '3C5V', '3QF7', '3SGR', '3SJH', '3TS9', '3TVT', '3U5V', '4DKL', '4EGC', '4I2A', '4IWB', '4M48', '4MBS', '5KLH', '3ZL8', '3ZLC', '3ZMD', '3ZN3', '3ZN4', '3ZN6', '3ZNC', '3ZNV', '3ZOJ', '3ZOQ', '3ZPX', '3ZQE', '3ZQO', '3ZQS', '3ZR8', '3ZRG', '3ZRI', '3ZRJ', '3ZRZ', '3ZS9', '3ZSU', '3ZT9', '3ZTV', '3ZUI', '3ZVL', '3ZVS', '3ZXC', '3ZXK', '3ZXN', '3ZY7', '3ZYP', '3ZZH', '3ZZO', '3ZZS', '3ZZY', '4A02', '4A0E', '4A0P', '4A15', '4NEC', '4NES', '4NG0', '4NHE', '4NI6', '4NJH', '4NJT', '4NJU', '4NJV', '4NK6', '4NL9', '4NM3', '4NMW', '4NMX', '4NMY', '4NN2', '4NN5', '4NNR', '4NOA', '4NOB', '4NOE', '4NPL', '4NPT', '4NQ0', '4NQJ', '4NRH', '4NS5', '4NSX', '4NT1', '4NTD', '4NUT', '4NV0', '4NWB', '5L20', '5LBD', '5LF9', '5LJP', '5MY5', '3M6Z', '3M7O', '3M89', '3M8J', '3M8P', '3M8U', '3M91', '3M9L', '3MAB', '3MAD', '3MAL', '3MAZ', '3MB5', '3MBK', '3MBR', '3MD1', '3MD7', '3MDM', '3MDU', '3ME0', '3MEE', '3MER', '3MFB', '3MGG', '3MHP', '3MHS', '3MHX', '3MI9', '3MIL', '3MIY', '3MJ6', '3MJE', '3MJH', '3MKC', '3ML1', '3MMG', '3MMH', '3MN2', '3MNE', '3MNM', '3MPC', '3MPK', '3MQ0', '3MQD', '1VHN', '1VHQ', '1VHT', '1VI0', '1VI4', '1VI6', '1VIM', '1VJQ', '1VJV', '1VK1', '1VPM', '1VR4', '1VR7', '2DPM', '2E2A', '2NLR', '3GM5', '4DS7', '4ODO', '4X86', '4XBU', '5AY6', '5B5Z', '5CDK', '5CG5', '5D5K', '5E3E', '5EIB', '5EUR', '5F5O', '5FFQ', '5GKX', '5GS7', '5O63', '5PMX', '3WVT', '3WVZ', '3WW3', '3WWN', '3WWQ', '3WX7', '3WYD', '3WZ3', '3WZD', '3WZE', '3WZS', '3X01', '3X0I', '3X0T', '3X0V', '3X2M', '3X30', '3X38', '3ZBD', '3ZBF', '3ZBO', '3ZDB', '3ZDO', '3ZE3', '3ZF8', '3ZFI', '3ZFP', '3ZG9', '3ZGH', '3ZGJ', '3ZH9', '3ZHI', '3ZHO', '3ZID', '3ZIE', '3ZIL', '3ZJ0', '3ZJA', '3ZJE', '5GXE', '5LTG', '3QF2', '3QFL', '3QFM', '3QFT', '3QGU', '3QH6', '3QH9', '3QHB', '3QHP', '3QHQ', '3QHY', '3QKS', '3QL9', '3QM9', '3QNM', '3QOO', ...

# %% [markdown]
# ## Visualize 3D structures of filtered structures

# %%
view_structure(filtered_structures)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Structure', max=9751), Output()…
# <function mmtfPyspark.structureViewer.view_structure.<locals>.view3d(i=0)>

# %% [markdown]
# ## Terminate Spark

# %%
spark.stop()
