# %% [markdown]
# # Filter By Release Date Demo
#
# This example demonstrates how to filter structure with specified release date range
#
# ## Imports

# %%
from pyspark import SparkConf, SparkContext
from mmtfPyspark.io import mmtfReader
from mmtfPyspark.filters import ReleaseDate
from mmtfPyspark.structureViewer import simple_structure_viewer

# %% [markdown]
# ## Configure Spark

# %%
conf = SparkConf().setMaster("local[*]") \
                      .setAppName("FilterByReleaseDate")
sc = SparkContext(conf = conf)

# %% [markdown]
# ## Read in MMTF Files, filter and count

# %%
path = "../../resources/mmtf_reduced_sample/"

structures = mmtfReader.read_sequence_file(path, sc) \
                .filter(ReleaseDate("2000-01-28","2017-02-28"))
        
print(f"Number of structure released between 2000-01-28 and 2017-02-28 is: {structures.count()}")
# Out:
# Number of structure released between 2000-01-28 and 2017-02-28 is: 5395

# %% [markdown]
# ## Visualize Structures

# %%
structure_names = structures.keys().collect()
simple_structure_viewer(structure_names, style='line')
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=5394), Output()), _dom_classes=('widget-interact',))
# <function mmtfPyspark.structureViewer.simple_structure_viewer.<locals>.view3d>

# %% [markdown]
# ## Terminate Spark

# %%
sc.stop()
